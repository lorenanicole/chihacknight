# %%
'''
(0. If you're in iPython, use magic for matplotlib.)
1. Import everything you think you need (you'll prob revise this later).
2. Read about the data.
3. Import the data.
4. Make a dataframe.
5. Clean the data.
6. Explore the data.

'''
""
# Out:
# ''

# %%
# %matplotlib inline

import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import vincent

# %%
path_for_file = os.path.expanduser("~") + "/projects/chihacknight/intermediate_python_for_data_analytics/311_Service_Requests_-_Graffiti_Removal.csv"

dateparse = lambda x: pd.datetime.strptime(x, '%m/%d/%Y')
df_raw = pd.read_csv(path_for_file, parse_dates=['Creation Date'], date_parser=dateparse)

# %%
df_raw_last_year = df_raw[df_raw["Creation Date"] > pd.datetime(2014,6,26)]

# %%
Series_surfaces = df_raw_last_ten_years["What Type of Surface is the Graffiti on?"].value_counts()

# %%
Series_surfaces.plot(kind="bar")

# %%
df_raw_last_year["ZIP Code"].value_counts().plot(kind="bar", figsize=(100,20))

# %%
df_raw.irow(0)["Creation Date"].
# Out:
# Timestamp('2015-06-28 00:00:00')
